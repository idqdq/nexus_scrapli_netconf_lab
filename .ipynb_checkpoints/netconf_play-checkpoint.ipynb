# %%
def xpath2xml(xpath, xmlns=''):
    
    pl = xpath.split('/')

    xmls = f'<{pl[1]} xmlns="{xmlns}">'
    xmle = f'</{pl[1]}>'
     
    def _xpath2xml(pl):
        key = ''
        xmls = ''
        xmle = ''

        for i in range(len(pl)):
            elem = pl[i]
            if "=" in elem:
                elem,key = elem.split("=")
                xmls += f'<{elem}>{key}</{elem}>'
                break
            xmls += f'<{elem}>'
            xmle = f'</{elem}>' + xmle
     
        if key and i < len(pl)-1:
            return xmls + _xpath2xml(pl[(i+1)::]) + xmle #recursion
        else:
            return xmls + xmle
     
    return xmls + _xpath2xml(pl[2::]) + xmle

# %%
from scrapli_netconf.driver import AsyncNetconfScrape
my_device = {
    "host": "192.168.99.91",
    "auth_username": "apiuser",
    "auth_password": "apipassword",
    "auth_strict_key": False,
    "transport": "asyncssh",
}

conn = AsyncNetconfScrape(**my_device)
await conn.open()
xmlns = "http://cisco.com/ns/yang/cisco-nx-os-device"

# %%
xpath = "/System/eps-items/epId-items"
xpath2xml(xpath, xmlns)

response = await conn.get(filter_=xpath2xml(xpath, xmlns), filter_type="subtree")
print(response.result)
# Out:
# <rpc-reply xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" message-id="101">
#   <data>
#     <System xmlns="http://cisco.com/ns/yang/cisco-nx-os-device">
#       <eps-items>
#         <epId-items>
#           <Ep-list>
#             <epId>1</epId>
#             <adminSt>enabled</adminSt>
#             <adminStMultisiteBrdrGwLoopackIntf>disabled</adminStMultisiteBrdrGwLoopackIntf>
#             <advertiseVmac>false</advertiseVmac>
#             <autoRemapReplicationServers>false</autoRemapReplicationServers>
#             <cfgSrc>unknown</cfgSrc>
#             <controllerId>0</controllerId>
#             <delayRestoreMsBrdrGwExpiryTime>NA</delayRestoreMsBrdrGwExpiryTime>
#             <delayRestoreMsBrdrGwTime>0</delayRestoreMsBrdrGwTime>
#             <encapType>unknown</encapType>
#             <holdDownTime>180</holdDownTime>
#             <holdDownTimerExpiryTime>NA</holdDownTimerExpiryTime>
#             <holdUpTime>30</holdUpTime>
#             <holdUpTimerExpiryTime>NA</holdUpTimerExpiryTime>
#             <hostReach>bgp</hostReach>
#             <ingressReplProtoBGP>false</ingressReplProtoBGP>
#             <learningMode>CP</learningMode>
#             <mac>A8:B4:56:AE:F2:77</mac>
#             <multisiteBrdrGwIntfIp>0.0.0.0</multisiteBrdrGwIntfIp>
#             <nws-items>
#               <opervni-items>
#                 <OperNw-list>
#                   <vni>10030</vni>
#                   <epId>1</epId>
#                   <mode>CP</mode>
#                   <operMcastGroup>230.1.1.1</operMcastGroup>
#                   <operSupprARP>false</operSupprARP>
#                   <state>Up</state>
#                   <type>L2</type>
#                   <vlanBD>vlan-30</vlanBD>
#                 </OperNw-list>
#                 <OperNw-list>
#                   <vni>10020</vni>
#                   <epId>1</epId>
#                   <mode>CP</mode>
#                   <operMcastGroup>230.1.1.1</operMcastGroup>
#                   <operSupprARP>false</operSupprARP>
#                   <state>Up</state>
#                   <type>L2</type>
#                   <vlanBD>vlan-20</vlanBD>
#                 </OperNw-list>
#               </opervni-items>
#               <vni-items>
#                 <Nw-list>
#                   <vni>10030</vni>
#                   <associateVrfFlag>false</associateVrfFlag>
#                   <isLegacyMode>false</isLegacyMode>
#                   <mcastGroup>230.1.1.1</mcastGroup>
#                   <multisiteIngRepl>disable</multisiteIngRepl>
#                   <spineAnyCastGw>false</spineAnyCastGw>
#                   <suppressARP>off</suppressARP>
#                 </Nw-list>
#                 <Nw-list>
#                   <vni>10020</vni>
#                   <associateVrfFlag>false</associateVrfFlag>
#                   <isLegacyMode>false</isLegacyMode>
#                   <mcastGroup>230.1.1.1</mcastGroup>
#                   <multisiteIngRepl>disable</multisiteIngRepl>
#                   <spineAnyCastGw>false</spineAnyCastGw>
#                   <suppressARP>off</suppressARP>
#                 </Nw-list>
#               </vni-items>
#             </nws-items>
#             <operAdvertiseVmac>false</operAdvertiseVmac>
#             <operEncapType>vxlan</operEncapType>
#             <operIfHandle>1224736769</operIfHandle>
#             <operNveFlags>unspecified</operNveFlags>
#             <operNveIfSt>NveIfAddComplete</operNveIfSt>
#             <operStAnycastSrcIntf>down</operStAnycastSrcIntf>
#             <operStMultisiteBgwIfDwnReason>N/A</operStMultisiteBgwIfDwnReason>
#             <operStMultisiteBrdrGwLoopbackIntf>down</operStMultisiteBrdrGwLoopbackIntf>
#             <operStSrcLoopbackIntf>up</operStSrcLoopbackIntf>
#             <operState>up</operState>
#             <primaryIp>1.1.1.1</primaryIp>
#             <primaryIpv6/>
#             <secondaryIp>1.1.1.254</secondaryIp>
#             <secondaryIpv6/>
#             <sourceInterface>lo0</sourceInterface>
#             <suppressARP>false</suppressARP>
#             <suppressMacRoute>false</suppressMacRoute>
#             <virtualRtrMac>02:00:01:01:01:FE</virtualRtrMac>
#             <virtualRtrMacReorig>00:00:00:00:00:00</virtualRtrMacReorig>
#             <vpcVIPNotified>true</vpcVIPNotified>
#           </Ep-list>
#         </epId-items>
#       </eps-items>
#     </System>
#   </data>
# </rpc-reply>

# %%
conf_tpl="""
<config>
    <System xmlns="http://cisco.com/ns/yang/cisco-nx-os-device">
        <bd-items>
            <bd-items>
                <BD-list>
                    <fabEncap>vlan-{vlan_id}</fabEncap>
                    <name>{vlan_name}</name>
                    <BdState>active</BdState>
                    <accEncap>vxlan-{vni}</accEncap>
                    <adminSt>active</adminSt>
                    <bridgeMode>mac</bridgeMode>
                    <fwdCtrl>mdst-flood</fwdCtrl>
                    <fwdMode>bridge,route</fwdMode>
                    <id>{vlan_id}</id>
                    <mode>CE</mode>
                </BD-list>
            </bd-items>
        </bd-items>
        <intf-items>
            <svi-items>
                <If-list>
                    <id>vlan{vlan_id}</id>
                    <mtu>{mtu}</mtu>
                    <descr>{description}</descr>
                    <adminSt>up</adminSt>
                    <rtvrfMbr-items>
                        <tDn>/System/inst-items/Inst-list[name='{vrf_name}']</tDn>
                    </rtvrfMbr-items>
                    <vlanId>{vlan_id}</vlanId>
                </If-list>
            </svi-items>
        </intf-items>
        <ipv4-items>
            <inst-items>
                <dom-items>
                    <Dom-list>
                        <name>{vrf_name}</name>
                        <if-items>
                            <If-list>
                                <id>vlan{vlan_id}</id>
                                <addr-items>
                                    <Addr-list>
                                        <addr>{ip_addr}</addr>
                                    </Addr-list>
                                </addr-items>
                            </If-list>
                        </if-items>
                    </Dom-list>
                </dom-items>
            </inst-items>
        </ipv4-items>
        <hmm-items>
            <fwdinst-items>
                <if-items>
                    <FwdIf-list>
                        <id>vlan{vlan_id}</id>
                        <adminSt>enabled</adminSt>
                        <mode>anycastGW</mode>
                    </FwdIf-list>
                </if-items>
            </fwdinst-items>
        </hmm-items>
        <eps-items>
            <epId-items>
                <Ep-list>
                    <epId>1</epId>
                    <nws-items>
                        <vni-items>
                            <Nw-list>
                                <vni>{vni}</vni>
                                <mcastGroup>230.1.1.2</mcastGroup>                                
                                <suppressARP>{supARP}</suppressARP>
                            </Nw-list>
                        </vni-items>
                    </nws-items>
                </Ep-list>
            </epId-items>
        </eps-items>
        <evpn-items>
            <adminSt>enabled</adminSt>
            <bdevi-items>
                <BDEvi-list>
                    <encap>vxlan-{vni}</encap>
                    <rd>rd:unknown:0:0</rd>
                    <rttp-items>
                        <RttP-list>
                            <type>export</type>
                            <ent-items>
                                <RttEntry-list>
                                    <rtt>route-target:unknown:0:0</rtt>
                                </RttEntry-list>
                            </ent-items>
                        </RttP-list>
                        <RttP-list>
                            <type>import</type>
                            <ent-items>
                                <RttEntry-list>
                                    <rtt>route-target:unknown:0:0</rtt>
                                </RttEntry-list>
                            </ent-items>
                        </RttP-list>
                    </rttp-items>
                </BDEvi-list>
            </bdevi-items>
        </evpn-items>
    </System>
</config>
"""

# %%
data=dict(vlan_id=120, vni=10120)          

conf = conf_tpl.format(vlan_id=data['vlan_id'], 
                       vni=data['vni'], 
                       vlan_name=data.get('vlan_name', 'VLAN{}'.format(data["vlan_id"])), 
                       description=data.get('description', 'created by netconf'), 
                       vrf_name=data.get('vrf_name', 'Tenant-1'), 
                       ip_addr=data.get('ip_addr', '10.1.{}.254/24'.format(data["vlan_id"])),
                       mgroup = data.get('mgroup', '230.1.1.1'),
                       supARP=data.get('supARP', 'off'), 
                       mtu=data.get('mtu', 1500))

response = await conn.edit_config(config=conf, target="running")
print(response.result)
# Out:
# <rpc-reply xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" message-id="101">
#   <ok/>
# </rpc-reply>

# %%
path = "/System/evpn-items"
response = await conn.get(filter_=xpath2xml(path, xmlns), filter_type="subtree")
print(response.result)
# Out:
# <rpc-reply xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" message-id="101">
#   <data>
#     <System xmlns="http://cisco.com/ns/yang/cisco-nx-os-device">
#       <evpn-items>
#         <adminSt>enabled</adminSt>
#         <bdevi-items>
#           <BDEvi-list>
#             <encap>vxlan-10126</encap>
#             <rd>rd:unknown:0:0</rd>
#             <rttp-items>
#               <RttP-list>
#                 <type>import</type>
#                 <ent-items>
#                   <RttEntry-list>
#                     <rtt>route-target:unknown:0:0</rtt>
#                   </RttEntry-list>
#                 </ent-items>
#                 <operRttAuto>route-target:as2-nn2:65000:10126</operRttAuto>
#               </RttP-list>
#               <RttP-list>
#                 <type>export</type>
#                 <ent-items>
#                   <RttEntry-list>
#                     <rtt>route-target:unknown:0:0</rtt>
#                   </RttEntry-list>
#                 </ent-items>
#                 <operRttAuto>route-target:as2-nn2:65000:10126</operRttAuto>
#               </RttP-list>
#             </rttp-items>
#             <tblMapFltr>false</tblMapFltr>
#           </BDEvi-list>
#           <BDEvi-list>
#             <encap>vxlan-10030</encap>
#             <operRd>rd:ipv4-nn2:1.1.1.1:32797</operRd>
#             <rd>rd:unknown:0:0</rd>
#             <rttp-items>
#               <RttP-list>
#                 <type>export</type>
#                 <ent-items>
#                   <RttEntry-list>
#                     <rtt>route-target:unknown:0:0</rtt>
#                   </RttEntry-list>
#                 </ent-items>
#               </RttP-list>
#               <RttP-list>
#                 <type>import</type>
#                 <ent-items>
#                   <RttEntry-list>
#                     <rtt>route-target:unknown:0:0</rtt>
#                   </RttEntry-list>
#                 </ent-items>
#               </RttP-list>
#             </rttp-items>
#             <tblMap/>
#             <tblMapFltr>false</tblMapFltr>
#           </BDEvi-list>
#           <BDEvi-list>
#             <encap>vxlan-10020</encap>
#             <operRd>rd:ipv4-nn2:1.1.1.1:32787</operRd>
#             <rd>rd:unknown:0:0</rd>
#             <rttp-items>
#               <RttP-list>
#                 <type>export</type>
#                 <ent-items>
#                   <RttEntry-list>
#                     <rtt>route-target:unknown:0:0</rtt>
#                   </RttEntry-list>
#                 </ent-items>
#               </RttP-list>
#               <RttP-list>
#                 <type>import</type>
#                 <ent-items>
#                   <RttEntry-list>
#                     <rtt>route-target:unknown:0:0</rtt>
#                   </RttEntry-list>
#                 </ent-items>
#               </RttP-list>
#             </rttp-items>
#             <tblMap/>
#             <tblMapFltr>false</tblMapFltr>
#           </BDEvi-list>
#           <BDEvi-list>
#             <encap>vxlan-10333</encap>
#             <operRd>rd:ipv4-nn2:1.1.1.1:33100</operRd>
#             <rd>rd:unknown:0:0</rd>
#             <rttp-items>
#               <RttP-list>
#                 <type>export</type>
#                 <ent-items>
#                   <RttEntry-list>
#                     <rtt>route-target:unknown:0:0</rtt>
#                   </RttEntry-list>
#                 </ent-items>
#               </RttP-list>
#               <RttP-list>
#                 <type>import</type>
#                 <ent-items>
#                   <RttEntry-list>
#                     <rtt>route-target:unknown:0:0</rtt>
#                   </RttEntry-list>
#                 </ent-items>
#               </RttP-list>
#             </rttp-items>
#             <tblMapFltr>false</tblMapFltr>
#           </BDEvi-list>
#           <BDEvi-list>
#             <encap>vxlan-10444</encap>
#             <operRd>rd:ipv4-nn2:1.1.1.1:33211</operRd>
#             <rd>rd:unknown:0:0</rd>
#             <rttp-items>
#               <RttP-list>
#                 <type>export</type>
#                 <ent-items>
#                   <RttEntry-list>
#                     <rtt>route-target:unknown:0:0</rtt>
#                   </RttEntry-list>
#                 </ent-items>
#               </RttP-list>
#               <RttP-list>
#                 <type>import</type>
#                 <ent-items>
#                   <RttEntry-list>
#                     <rtt>route-target:unknown:0:0</rtt>
#                   </RttEntry-list>
#                 </ent-items>
#               </RttP-list>
#             </rttp-items>
#             <tblMapFltr>false</tblMapFltr>
#           </BDEvi-list>
#         </bdevi-items>
#         <operSt>enabled</operSt>
#       </evpn-items>
#     </System>
#   </data>
# </rpc-reply>

# %%
conn.close()
# Out:
# <coroutine object AsyncScrape.close at 0x7f73fe7a4b40>
